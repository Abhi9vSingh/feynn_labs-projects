# %% [markdown]
# ##  1. Full Body Checkup with a Bio-Tech Device based on Blood Samples  Online Health Techs offering
# ##### i. Diabetes checkup device
# ##### ii. Blood Pressure checkup device
# ##### iii. Vitamins deficiency checkup device
# You have to analyse Medical Market in India with respect to the given problem statement using Segmentation analysis
#
# # Geographic, Demographic, Psychographic, Behavioral.

# %% [markdown]
# ![image.png](attachment:53b644e7-c831-43eb-8c97-dba93b15f8b6.png)

# %% [markdown]
# # Geogrophic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\YOGESH~1\AppData\Local\Temp/ipykernel_5776/1468614551.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import plotly.express as px
#       6 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'plotly'

# %%
data= pd.read_csv('state_wise_population__2019.csv')
data.head(8)
# Out:
#    State population_total  population_male  population_female
# 0      1        JHARKHAND          4278259            4278259
# 1      2          MANIPUR           264986             128931
# 2      3          GUJARAT         17835049            9541688
# 3      4      WEST BENGAL         18063509            9357777
# 4      5       TAMIL NADU         13879395            6957261
# 5      6     NCT OF DELHI         13481997            7201322
# 6      7            ASSAM          1391154             720132
# 7      8   MADHYA PRADESH         11023091            5761143

# %%
data.isnull().sum()
# Out:
# State                0
# population_total     0
# population_male      0
# population_female    0
# dtype: int64

# %%
data['total']=data['population_male']+data['population_female']

# %%
data
# Out:
#     State           population_total  population_male  population_female  \
# 0       1                  JHARKHAND          4278259            4278259
# 1       2                    MANIPUR           264986             128931
# 2       3                    GUJARAT         17835049            9541688
# 3       4                WEST BENGAL         18063509            9357777
# 4       5                 TAMIL NADU         13879395            6957261
# 5       6               NCT OF DELHI         13481997            7201322
# 6       7                      ASSAM          1391154             720132
# 7       8             MADHYA PRADESH         11023091            5761143
# 8       9                MAHARASHTRA         37722136           19961736
# 9      10                      BIHAR          6714516            3558722
# 10     11                    HARYANA          5952223            3181968
# 11     12               CHHATTISGARH          3137918            1612019
# ...

# %%
data.plot(x= 'population_total', y ='total', kind = 'bar',
        title ='Population', grid=True)
# Out:
# <AxesSubplot:title={'center':'Population'}, xlabel='population_total'>
